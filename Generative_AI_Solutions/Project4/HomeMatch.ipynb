# %%
# Import all the required modules
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.memory import ChatMessageHistory
from langchain.schema import HumanMessage

# %%
import os

# Set the API key and the base url
API_KEY = "" # API KEY
API_BASE = "https://openai.vocareum.com/v1"

os.environ["OPENAI_API_KEY"] =  API_KEY 
os.environ["OPENAI_API_BASE"] = API_BASE

# %%
model_name = "gpt-3.5-turbo" # Set the Model name
temperature = 0.5 # Higher the temperature, more creative the response
llm = ChatOpenAI(model_name=model_name, temperature=temperature, max_tokens=1000)

# %%
# To get the consistent response in JSON format, define a schema for the response
from langchain.output_parsers import StructuredOutputParser, ResponseSchema

response_schema = [
    ResponseSchema(
        name="Neighborhood", description="Name of the neighborhood", type="string"
    ),
    ResponseSchema(name="Price", description="Property price in USD", type="float"),
    ResponseSchema(name="Bedrooms", description="Number of bedrooms", type="integer"),
    ResponseSchema(name="Bathrooms", description="Number of bathrooms", type="integer"),
    ResponseSchema(
        name="House Size", description="Size of the house in square feet", type="float"
    ),
    ResponseSchema(
        name="Description",
        description="A short description of the property",
        type="string",
    ),
    ResponseSchema(
        name="Neighborhood Description",
        description="Description of the neighborhood",
        type="string",
    ),
]

# Create a parser that enforeces the schema
output_parser = StructuredOutputParser.from_response_schemas(response_schema)

# %%
# Get the format instructions (used in the prompt)
format_instructions = output_parser.get_format_instructions()

# %%
# A history to store the chat messages
history = ChatMessageHistory()

# %%
example_listing = """
"Neighborhood": "Green Oaks"
"Price": 800000.0
"Bedrooms": 3
"Bathrooms": 2
"House Size": 2000.0

"Description": "Welcome to this eco-friendly oasis nestled in the heart of Green Oaks. This charming 3-bedroom, 2-bathroom home boasts energy-efficient features such as solar panels and a well-insulated structure. Natural light floods the living spaces, highlighting the beautiful hardwood floors and eco-conscious finishes. The open-concept kitchen and dining area lead to a spacious backyard with a vegetable garden, perfect for the eco-conscious family. Embrace sustainable living without compromising on style in this Green Oaks gem."

"Neighborhood Description": "Green Oaks is a close-knit, environmentally-conscious community with access to organic grocery stores, community gardens, and bike paths. Take a stroll through the nearby Green Oaks Park or grab a cup of coffee at the cozy Green Bean Cafe. With easy access to public transportation and bike lanes, commuting is a breeze."
"""

# %%
# Define the base prompt
prompt_template = ChatPromptTemplate.from_template(
    "You are a real estate listing generator.\n"
    "Generate ONE unique and realistic property listing in the exact format specified below.\n"
    "Make sure this listing is different from all previously generated ones in the conversation.\n"
    "Also  vary the city name, price, size, bedrooms, bathrooms and so on.\n"
    "{format_instructions}\n"
    "Ensure valid JSON only — no explanations or markdown."
    "Below is the example of desired format for listings: \n"
    f"{example_listing}\n"
    "Ensure to cover bedrooms, bathrooms, space and others into the description field"
    "Ensure when generating, Number of Bathrooms, Bedrooms are integer not float"
    "Ensure to generate diverse number of Bedrooms ranging from 2 to 5 nos"
    "Also Ensure to generate diverse number of Bathrooms ranging from 2 to 5 nos "
)

# %%
import json

n = 10  # Change here to change the number of data generated in the listings
listings = []

# To ensure that the data that is getting generated from LLM are always unique, we added chat history to look back the generated data.
for i in range(n):
    formatted_prompt = prompt_template.format(format_instructions=format_instructions)
    messages = history.messages + [HumanMessage(content=formatted_prompt)]
    response = llm.invoke(messages)
    parsed = output_parser.parse(response.content)
    listings.append(parsed)

    # Add model's response to the chat history (this helps us to generate unique data as this has the data of what it previously generated)
    history.add_user_message(f"Generated listing {i+1}: {json.dumps(parsed)}")
    history.add_ai_message(
        "Got it, I will avoid generating similar listings in the next iteration"
    )

# %%
# Store the JSON listings in a file
json_file = "real_estate_listing.json"

with open(json_file, "w", encoding="utf-8") as f:
    json.dump({"real_estate_listings": listings}, f, indent=2, ensure_ascii=False)

# %%
# Read the json object from file
import json

with open("real_estate_listing.json", "r") as f:
    data = json.load(f)["real_estate_listings"]

# %%
from langchain.embeddings import OpenAIEmbeddings

embedding_model = OpenAIEmbeddings(model="text-embedding-3-large")
embedding_dim = 3072

# %%
# Create and store the embeddings for the text description which captures the semantic meaning of the text 
embeddings = []
for i in range(len(data)):
    text = "Description: "  + data[i]["Description"] + "\nNeighborhood: " + data[i]["Neighborhood Description"]
    print(text)
    embedding = embedding_model.embed_query(text)
    embeddings.append(embedding)
# Out:
# Description: Discover this spacious 4-bedroom, 3-bathroom home in the desirable Willow Creek neighborhood. The open floor plan features a gourmet kitchen with granite countertops and stainless steel appliances, perfect for entertaining guests. The master suite offers a relaxing retreat with a luxurious en-suite bathroom and walk-in closet. Enjoy the outdoor patio and large backyard, ideal for summer BBQs and gatherings. This home is perfect for families looking for comfort and style in Willow Creek.
# Neighborhood: Willow Creek is known for its family-friendly atmosphere and top-rated schools. Residents enjoy easy access to parks, shopping centers, and dining options. Take a leisurely stroll along the tree-lined streets or visit the nearby Willow Creek Country Club for golf and social events.
# Description: Step into luxury in this stunning 5-bedroom, 4-bathroom home located in the prestigious Sunset Hills neighborhood. The grand entrance leads to a spacious living room with high ceilings and a cozy fireplace. The gourmet kitchen features top-of-the-line appliances and a large island, perfect for culinary enthusiasts. The master suite offers a private sanctuary with a spa-like bathroom and walk-in closet. Enjoy the beautifully landscaped backyard with a pool and spa, ideal for relaxation and entertainment. Experience elegance and comfort in Sunset Hills.
# Neighborhood: Sunset Hills is renowned for its upscale living and scenic views. Residents can explore nearby hiking trails, boutique shops, and fine dining restaurants. The neighborhood is known for its sense of community and exclusive amenities, making it a desirable place to call home.
# Description: Welcome to this cozy 3-bedroom, 2-bathroom home in the charming Maple Grove neighborhood. The inviting living room features a fireplace, perfect for relaxing evenings. The kitchen is equipped with modern appliances and a breakfast nook, ideal for casual dining. The master bedroom offers a peaceful retreat with an en-suite bathroom. Step outside to the well-maintained backyard with a deck, great for outdoor gatherings. Experience comfort and warmth in this Maple Grove gem.
# Neighborhood: Maple Grove is known for its tranquil setting and friendly community atmosphere. Residents can enjoy nearby parks, cafes, and local shops. The neighborhood provides easy access to walking trails and recreational activities, making it a wonderful place for families and nature enthusiasts.
# Description: Discover serenity in this elegant 4-bedroom, 3-bathroom home nestled in the sought-after Pinecrest Hills neighborhood. The spacious living room features large windows that fill the space with natural light, highlighting the hardwood floors and modern finishes. The gourmet kitchen is a chef's dream with high-end appliances and a center island. Retreat to the luxurious master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a patio, perfect for outdoor entertaining. Experience luxury living in Pinecrest Hills.
# Neighborhood: Pinecrest Hills is known for its upscale living and scenic beauty. Residents enjoy access to hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of tranquility and exclusivity, making it a desirable place to call home.
# Description: Step into luxury in this magnificent 5-bedroom, 4-bathroom home located in the prestigious Riverbend Estates. The grand foyer welcomes you into a spacious living area with high ceilings and elegant architectural details. The chef's kitchen is equipped with top-of-the-line appliances and a center island, perfect for culinary enthusiasts. The master suite offers a private retreat with a spa-like bathroom and dual walk-in closets. Enjoy the beautifully landscaped backyard with a pool and outdoor kitchen, ideal for entertaining guests. Experience upscale living at its finest in Riverbend Estates.
# Neighborhood: Riverbend Estates is a highly sought-after community known for its upscale homes and scenic surroundings. Residents can enjoy nearby hiking trails, exclusive boutiques, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a prime location for those seeking luxury living.
# Description: Experience luxury living in this spacious 4-bedroom, 3-bathroom home situated in the prestigious Lakeview Heights neighborhood. The grand entrance opens to a bright and airy living room with high ceilings and elegant hardwood floors. The gourmet kitchen features top-of-the-line appliances and a breakfast bar, perfect for hosting gatherings. Retreat to the master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor relaxation. Embrace comfort and sophistication in this Lakeview Heights gem.
# Neighborhood: Lakeview Heights is known for its upscale homes and picturesque views of the nearby lake. Residents can enjoy leisurely walks around the neighborhood or visit the local vineyards for wine tasting. With easy access to hiking trails and boutique shops, Lakeview Heights offers a serene and luxurious lifestyle.
# Description: Discover elegance in this 4-bedroom, 3-bathroom home located in the prestigious Golden Hills neighborhood. The inviting living room features a cozy fireplace and large windows that fill the space with natural light. The gourmet kitchen boasts granite countertops and stainless steel appliances, perfect for culinary enthusiasts. Retreat to the master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a deck, ideal for outdoor gatherings. Experience luxury living in Golden Hills.
# Neighborhood: Golden Hills is renowned for its upscale homes and scenic views of the surrounding hills. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Step into luxury in this beautiful 4-bedroom, 3-bathroom home located in the desirable Sunnyvale Heights neighborhood. The spacious living room features large windows that offer abundant natural light and showcase the stunning hardwood floors. The gourmet kitchen is equipped with high-end appliances and a breakfast bar, perfect for hosting family and friends. Retreat to the master suite with a luxurious en-suite bathroom and walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor entertaining. Experience comfort and elegance in this Sunnyvale Heights gem.
# Neighborhood: Sunnyvale Heights is known for its family-friendly environment and convenient location. Residents can enjoy nearby parks, shopping centers, and restaurants. The neighborhood offers easy access to schools and community events, making it a great place for families and professionals alike.
# Description: Luxury awaits in this exquisite 5-bedroom, 4-bathroom home situated in the prestigious Harbor View Estates neighborhood. The grand foyer leads to a spacious living room with high ceilings and elegant architectural details. The chef's kitchen is equipped with top-of-the-line appliances and a center island, perfect for entertaining. Retreat to the lavish master suite with a spa-like bathroom and dual walk-in closets. Step outside to the landscaped backyard with a pool and outdoor kitchen, ideal for hosting gatherings. Experience upscale living at its finest in Harbor View Estates.
# Neighborhood: Harbor View Estates is known for its upscale homes and breathtaking views of the harbor. Residents can enjoy nearby marinas, yacht clubs, and upscale dining options. The neighborhood offers a sense of exclusivity and luxury, making it a prime location for those seeking a sophisticated lifestyle.
# Description: Discover tranquility in this elegant 4-bedroom, 3-bathroom home located in the serene Meadowbrook Hills neighborhood. The spacious living room features vaulted ceilings and a cozy fireplace, creating a warm and inviting atmosphere. The gourmet kitchen is equipped with stainless steel appliances and granite countertops, perfect for culinary enthusiasts. Retreat to the master suite with a luxurious en-suite bathroom and a walk-in closet. Step outside to the landscaped backyard with a deck, ideal for outdoor gatherings. Experience comfort and sophistication in Meadowbrook Hills.
# Neighborhood: Meadowbrook Hills offers a peaceful setting with tree-lined streets and friendly neighbors. Residents can enjoy nearby parks, hiking trails, and local cafes. The neighborhood provides a sense of community and relaxation, making it a perfect place for families and nature lovers.
# Description: Welcome to this elegant 4-bedroom, 3-bathroom home perched in the prestigious Hillside Heights neighborhood. The grand entrance leads to a spacious living room with high ceilings and large windows that offer stunning views of the surrounding hills. The chef's kitchen features top-of-the-line appliances and a breakfast nook, perfect for morning gatherings. Retreat to the luxurious master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor entertaining. Experience luxury living in Hillside Heights.
# Neighborhood: Hillside Heights is known for its upscale homes and panoramic views of the city skyline. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Discover modern elegance in this 4-bedroom, 3-bathroom home located in the prestigious Oakwood Estates. The open-concept living area boasts high ceilings and large windows that flood the space with natural light. The gourmet kitchen features sleek appliances and a center island, perfect for culinary enthusiasts. Retreat to the master suite with a spa-like bathroom and walk-in closet. Step outside to the landscaped backyard with a pergola, ideal for outdoor relaxation. Experience luxury living in Oakwood Estates.
# Neighborhood: Oakwood Estates offers a blend of upscale living and natural beauty. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood provides a sense of tranquility and exclusivity, making it a desirable place to call home.
# Description: Step into luxury in this elegant 4-bedroom, 3-bathroom home located in the prestigious Crestview Heights neighborhood. The grand foyer opens to a spacious living room with high ceilings and a cozy fireplace. The gourmet kitchen features top-of-the-line appliances and a breakfast bar, perfect for entertaining. Retreat to the master suite with a spa-like bathroom and walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor gatherings. Experience sophistication and comfort in Crestview Heights.
# Neighborhood: Crestview Heights is known for its upscale homes and scenic views. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Indulge in luxury in this stunning 5-bedroom, 4-bathroom home nestled in the exclusive Pine Ridge Estates. The grand entrance leads to a spacious living room with high ceilings and a cozy fireplace. The chef's kitchen features top-of-the-line appliances and a large island, perfect for hosting elegant dinner parties. Retreat to the lavish master suite with a spa-like bathroom and dual walk-in closets. Step outside to the landscaped backyard with a pool and outdoor kitchen, ideal for entertaining guests. Experience upscale living at its finest in Pine Ridge Estates.
# Neighborhood: Pine Ridge Estates is known for its upscale homes and lush greenery. Residents can enjoy nearby country clubs, upscale shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a prime location for those seeking a sophisticated lifestyle.
# Description: Experience luxury living in this spacious 4-bedroom, 3-bathroom home situated in the prestigious Mountain View Estates. The grand entrance opens to a bright and airy living room with high ceilings and elegant hardwood floors. The gourmet kitchen is equipped with top-of-the-line appliances and a breakfast bar, perfect for hosting gatherings. Retreat to the master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor relaxation. Embrace comfort and sophistication in this Mountain View Estates gem.
# Neighborhood: Mountain View Estates is known for its upscale homes and scenic views of the surrounding mountains. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Step into luxury in this elegant 4-bedroom, 3-bathroom home located in the prestigious Sunset Ridge neighborhood. The grand entrance leads to a spacious living room with high ceilings and a cozy fireplace. The gourmet kitchen features top-of-the-line appliances and a center island, perfect for culinary enthusiasts. Retreat to the master suite with a spa-like bathroom and walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor gatherings. Experience sophistication and comfort in Sunset Ridge.
# Neighborhood: Sunset Ridge is known for its upscale homes and panoramic views of the city skyline. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Welcome to this spacious 5-bedroom, 3-bathroom home in the serene Cedar Valley neighborhood. The open floor plan features a bright living room with high ceilings and a cozy fireplace. The gourmet kitchen boasts granite countertops and stainless steel appliances, perfect for culinary enthusiasts. The master suite offers a retreat with a luxurious en-suite bathroom and walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor gatherings. Experience comfort and style in Cedar Valley.
# Neighborhood: Cedar Valley is known for its peaceful surroundings and friendly community atmosphere. Residents can enjoy nearby parks, hiking trails, and local cafes. The neighborhood provides a sense of tranquility and connection, making it a perfect place for families and nature lovers.
# Description: Luxury living awaits in this exquisite 5-bedroom, 4-bathroom home nestled in the prestigious Silver Creek Estates neighborhood. The grand entrance leads to a spacious living room with high ceilings and elegant architectural details. The chef's kitchen is equipped with top-of-the-line appliances and a center island, perfect for hosting elegant dinner parties. Retreat to the lavish master suite with a spa-like bathroom and dual walk-in closets. Step outside to the landscaped backyard with a pool and outdoor kitchen, ideal for entertaining guests. Experience upscale living at its finest in Silver Creek Estates.
# Neighborhood: Silver Creek Estates is known for its upscale homes and picturesque views of the surrounding hills. Residents can enjoy nearby country clubs, upscale shopping, and fine dining options. The neighborhood offers a sense of exclusivity and luxury, making it a prime location for those seeking a sophisticated lifestyle.
# Description: Discover elegance in this 4-bedroom, 3-bathroom home located in the prestigious Hilltop Heights neighborhood. The inviting living room features a cozy fireplace and large windows that fill the space with natural light. The gourmet kitchen boasts granite countertops and stainless steel appliances, perfect for culinary enthusiasts. Retreat to the master suite with a spa-like bathroom and walk-in closet. Step outside to the landscaped backyard with a deck, ideal for outdoor gatherings. Experience luxury living in Hilltop Heights.
# Neighborhood: Hilltop Heights is known for its upscale homes and panoramic views of the city skyline. Residents can enjoy nearby hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of exclusivity and tranquility, making it a desirable place to call home.
# Description: Luxury living at its finest in this magnificent 5-bedroom, 4-bathroom home located in the prestigious Willowbrook Estates. The grand entrance welcomes you into a spacious living room with high ceilings and a cozy fireplace. The chef's kitchen is equipped with top-of-the-line appliances and a large island, perfect for entertaining. Retreat to the lavish master suite with a spa-like bathroom and dual walk-in closets. Step outside to the landscaped backyard with a pool and outdoor kitchen, ideal for hosting elegant gatherings. Experience upscale living in Willowbrook Estates.
# Neighborhood: Willowbrook Estates is known for its upscale homes and lush greenery. Residents can enjoy nearby country clubs, upscale shopping, and fine dining options. The neighborhood offers a sense of exclusivity and luxury, making it a prime location for those seeking a sophisticated lifestyle.

# %%
import lancedb
from lancedb.pydantic import vector, LanceModel

# Define a data structure to store the generated data
class RealEstateData(LanceModel):
    Neighborhood: str
    Price: float
    Bedrooms: int
    Bathrooms: int
    House_Size: float
    Description: str
    Neighborhood_Description: str
    Embedding: vector(embedding_dim)  # type: ignore

# %%
import pyarrow as pa

# Create a database and a table inside it
db = lancedb.connect(".lancedb")
table_name = "real_estate_listings"
db.drop_table(table_name, ignore_missing=True)
table = db.create_table(table_name, schema=RealEstateData, mode="overwrite")

# %%
values = []

# Add the data to the database with corresponding embeddings
for i in range(len(data)):
    value = RealEstateData(
        Neighborhood=data[i]["Neighborhood"],
        Price=float(data[i]["Price"]),
        Bedrooms=int(data[i]["Bedrooms"]),
        Bathrooms=int(data[i]["Bathrooms"]),
        House_Size=float(data[i]["House Size"]),
        Description=data[i]["Description"],
        Neighborhood_Description=data[i]["Neighborhood Description"],
        Embedding=embeddings[i],
    )
    values.append(value)

table.add(values)
# Out:
# AddResult(version=2)

# %%
len(table)
# Out:
# 20

# %%
table.head().to_pandas()
# Out:
#         Neighborhood     Price  Bedrooms  Bathrooms  House_Size  \
# 0       Willow Creek  650000.0         4          3      2400.0
# 1       Sunset Hills  720000.0         5          4      2800.0
# 2        Maple Grove  580000.0         3          2      1800.0
# 3    Pinecrest Hills  690000.0         4          3      2500.0
# 4  Riverbend Estates  750000.0         5          4      3000.0
#
#                                          Description  \
# 0  Discover this spacious 4-bedroom, 3-bathroom h...
# 1  Step into luxury in this stunning 5-bedroom, 4...
# 2  Welcome to this cozy 3-bedroom, 2-bathroom hom...
# 3  Discover serenity in this elegant 4-bedroom, 3...
# 4  Step into luxury in this magnificent 5-bedroom...
#
#                             Neighborhood_Description  \
# 0  Willow Creek is known for its family-friendly ...
# 1  Sunset Hills is renowned for its upscale livin...
# 2  Maple Grove is known for its tranquil setting ...
# 3  Pinecrest Hills is known for its upscale livin...
# 4  Riverbend Estates is a highly sought-after com...
#
#                                            Embedding
# 0  [-0.014942469, 0.021715518, -0.008795829, 0.00...
# 1  [-0.020557083, 0.0053015635, -0.015885597, -0....
# 2  [-0.0031715953, 0.017896859, -0.010458713, 0.0...
# 3  [-0.026866933, 0.043429106, -0.017440872, -0.0...
# 4  [-0.013402212, 0.022879306, -0.019083304, -0.0...

# %%
from typing import Union

# Get the embedding for the query vector
def get_embedding(query: Union[str, list[str]]):
    query_filtered = " ".join(query)
    return embedding_model.embed_query(query_filtered)

# %%
# Input here the user prompt
query = "A cozy three-bedroom house with spacious kitchen and friendly neighborhood"

# %%
# Query the LanceDB to find the matching listings
k = 5  # Change this to get the top k matching results for the given query
query_vector = get_embedding(query)
results = table.search(query_vector).metric("cosine").limit(k).to_pydantic(RealEstateData)

# %%
# for result in results:
#     val = f"Nieghborhood: {result['Neighborhood']}, Bedrooms: {result['Bedrooms']}, Bathroom: {result['Bathrooms']}, Distance: {result['_distance']}"
#     print(val)

# %%
results
# Out:
# [RealEstateData(Neighborhood='Maple Grove', Price=580000.0, Bedrooms=3, Bathrooms=2, House_Size=1800.0, Description='Welcome to this cozy 3-bedroom, 2-bathroom home in the charming Maple Grove neighborhood. The inviting living room features a fireplace, perfect for relaxing evenings. The kitchen is equipped with modern appliances and a breakfast nook, ideal for casual dining. The master bedroom offers a peaceful retreat with an en-suite bathroom. Step outside to the well-maintained backyard with a deck, great for outdoor gatherings. Experience comfort and warmth in this Maple Grove gem.', Neighborhood_Description='Maple Grove is known for its tranquil setting and friendly community atmosphere. Residents can enjoy nearby parks, cafes, and local shops. The neighborhood provides easy access to walking trails and recreational activities, making it a wonderful place for families and nature enthusiasts.', Embedding=FixedSizeList(dim=3072)),
#  RealEstateData(Neighborhood='Meadowbrook Hills', Price=690000.0, Bedrooms=4, Bathrooms=3, House_Size=2500.0, Description='Discover tranquility in this elegant 4-bedroom, 3-bathroom home located in the serene Meadowbrook Hills neighborhood. The spacious living room features vaulted ceilings and a cozy fireplace, creating a warm and inviting atmosphere. The gourmet kitchen is equipped with stainless steel appliances and granite countertops, perfect for culinary enthusiasts. Retreat to the master suite with a luxurious en-suite bathroom and a walk-in closet. Step outside to the landscaped backyard with a deck, ideal for outdoor gatherings. Experience comfort and sophistication in Meadowbrook Hills.', Neighborhood_Description='Meadowbrook Hills offers a peaceful setting with tree-lined streets and friendly neighbors. Residents can enjoy nearby parks, hiking trails, and local cafes. The neighborhood provides a sense of community and relaxation, making it a perfect place for families and nature lovers.', Embedding=FixedSizeList(dim=3072)),
#  RealEstateData(Neighborhood='Cedar Valley', Price=720000.0, Bedrooms=5, Bathrooms=3, House_Size=2600.0, Description='Welcome to this spacious 5-bedroom, 3-bathroom home in the serene Cedar Valley neighborhood. The open floor plan features a bright living room with high ceilings and a cozy fireplace. The gourmet kitchen boasts granite countertops and stainless steel appliances, perfect for culinary enthusiasts. The master suite offers a retreat with a luxurious en-suite bathroom and walk-in closet. Step outside to the landscaped backyard with a patio, ideal for outdoor gatherings. Experience comfort and style in Cedar Valley.', Neighborhood_Description='Cedar Valley is known for its peaceful surroundings and friendly community atmosphere. Residents can enjoy nearby parks, hiking trails, and local cafes. The neighborhood provides a sense of tranquility and connection, making it a perfect place for families and nature lovers.', Embedding=FixedSizeList(dim=3072)),
#  RealEstateData(Neighborhood='Willow Creek', Price=650000.0, Bedrooms=4, Bathrooms=3, House_Size=2400.0, Description='Discover this spacious 4-bedroom, 3-bathroom home in the desirable Willow Creek neighborhood. The open floor plan features a gourmet kitchen with granite countertops and stainless steel appliances, perfect for entertaining guests. The master suite offers a relaxing retreat with a luxurious en-suite bathroom and walk-in closet. Enjoy the outdoor patio and large backyard, ideal for summer BBQs and gatherings. This home is perfect for families looking for comfort and style in Willow Creek.', Neighborhood_Description='Willow Creek is known for its family-friendly atmosphere and top-rated schools. Residents enjoy easy access to parks, shopping centers, and dining options. Take a leisurely stroll along the tree-lined streets or visit the nearby Willow Creek Country Club for golf and social events.', Embedding=FixedSizeList(dim=3072)),
#  RealEstateData(Neighborhood='Pinecrest Hills', Price=690000.0, Bedrooms=4, Bathrooms=3, House_Size=2500.0, Description="Discover serenity in this elegant 4-bedroom, 3-bathroom home nestled in the sought-after Pinecrest Hills neighborhood. The spacious living room features large windows that fill the space with natural light, highlighting the hardwood floors and modern finishes. The gourmet kitchen is a chef's dream with high-end appliances and a center island. Retreat to the luxurious master suite with a spa-like bathroom and a walk-in closet. Step outside to the landscaped backyard with a patio, perfect for outdoor entertaining. Experience luxury living in Pinecrest Hills.", Neighborhood_Description='Pinecrest Hills is known for its upscale living and scenic beauty. Residents enjoy access to hiking trails, boutique shopping, and fine dining options. The neighborhood offers a sense of tranquility and exclusivity, making it a desirable place to call home.', Embedding=FixedSizeList(dim=3072))]

# %%
system_prompt = """
You are an expert factual real estate content enhancer.
Given a property listing and a buyer's preferences:
1. Rewrite the original listing description to highlight features that match the buyer's interests.
2. Keep the description factual — do not invent or exaggerate details stick to the details of original listing description.
3. Maintain a natural and engaging tone suitable for property listings.
4. Important thing is preserve numeric details (bedrooms, bathrooms, and so on) from the Original description and only enhance the original description.
"""

# %%
from openai import OpenAI

client = OpenAI(
    api_key=API_KEY,
    base_url=API_BASE
)

def personalized_listing(prompt: str, listing: RealEstateData) -> str:  # type: ignore
    try:
        user_prompt = f"""
        User Preferences:
        {prompt}
        
        Original Description
        {listing.Description}
        
        Original Number of Bedrooms
        {listing.Bedrooms}
        
        Original Number of Bathrooms
        {listing.Bathrooms}
        
        Original Neighborhood Name
        {listing.Neighborhood}
        
        Neighborhood Description
        {listing.Neighborhood_Description}
        
        Task:
        Rewrite the description so it resonates with the buyer preferences, emphasizing only on aspects that match their preferences.
        Do not invent any details. Keep factual integrity.
        Ensure that the augmentation process enhances the appeal of the listing without altering factual information like the number of bedrooms and bathrooms mentioned in the Original Description.
        Use the number of bedrooms and bathrooms from the original description
        """

        # print(user_prompt)
        response = client.chat.completions.create(
            model="gpt-4o-mini",
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt},
            ],
            temperature=1,
            max_tokens=512,
            top_p=1,
            frequency_penalty=0,
            presence_penalty=0,
        )

        # print("Response: ", response.choices[0].message.content)
        # print("\n\n\n\n")
        # The response is a JSON object containing more information than the response. We want to return only the message content
        return response.choices[0].message.content
    except Exception as e:
        return f"An error occured: {e}"

# %%
personalized_listings = []
for listing in results:
    personalized_response = personalized_listing(query, listing)
    personalized_listings.append(personalized_response)

# %%
for listing in personalized_listings:
    print("\n" + "=" * 100 + "\n")
    print(listing)

print("\n" + "=" * 100 + "\n")
# Out:
# ====================================================================================================
#
# Welcome to this cozy 3-bedroom, 2-bathroom home nestled in the friendly neighborhood of Maple Grove. This inviting residence is designed for comfort, featuring a warm living room complete with a fireplace, perfect for those relaxing evenings spent with loved ones. The spacious kitchen is equipped with modern appliances and includes a breakfast nook, making it an ideal spot for casual dining and morning gatherings.
#
# The master bedroom provides a peaceful retreat, featuring an en-suite bathroom for added convenience. Outside, you'll find a well-maintained backyard with a deck that’s perfect for outdoor gatherings, offering a wonderful space to connect with family and friends.
#
# Maple Grove is renowned for its tranquil atmosphere and welcoming community, where residents enjoy nearby parks, local shops, and easy access to walking trails. This charming neighborhood is perfect for families and nature enthusiasts looking to embrace a vibrant lifestyle. Experience the warmth and comfort of this Maple Grove gem!
#
# ====================================================================================================
#
# Welcome to this charming 4-bedroom, 3-bathroom home nestled in the friendly and serene Meadowbrook Hills neighborhood. This residence offers a warm and inviting atmosphere, featuring a spacious living room with vaulted ceilings and a cozy fireplace, perfect for relaxation.
#
# While the gourmet kitchen is designed for culinary enthusiasts with stainless steel appliances and granite countertops, it also invites family gatherings and friendly interactions.
#
# The master suite provides a comfortable retreat, complete with a luxurious en-suite bathroom and a convenient walk-in closet. Step outside into the beautifully landscaped backyard, where a deck awaits — an ideal setting for outdoor gatherings with friends and family.
#
# Experience a sense of community in Meadowbrook Hills, where tree-lined streets and friendly neighbors create a tranquil environment. Enjoy access to nearby parks, hiking trails, and local cafes, making this an ideal neighborhood for families and nature lovers alike. Your cozy oasis awaits!
#
# ====================================================================================================
#
# Discover this inviting 3-bedroom, 2-bathroom home nestled in the friendly Cedar Valley neighborhood, perfect for those seeking comfort and community. The spacious layout is enhanced by an open floor plan that welcomes you into a bright living room, ideal for relaxation with its cozy ambiance. The delightful kitchen, although not originally highlighted, presents ample space for culinary adventures and gatherings with loved ones. The beautifully landscaped backyard offers a serene space for outdoor enjoyment, perfect for BBQs or simply unwinding in nature. Cedar Valley is celebrated for its peaceful surroundings, with a strong sense of community among residents. Enjoy the nearby parks and hiking trails, creating endless opportunities for family outings and outdoor activities. Experience the perfect blend of comfort and neighborly charm in Cedar Valley.
#
# ====================================================================================================
#
# Welcome to this inviting 4-bedroom, 3-bathroom home nestled in the friendly Willow Creek neighborhood. The open floor plan features a spacious gourmet kitchen equipped with granite countertops and stainless steel appliances, making it a perfect gathering spot for family and friends. The master suite provides a cozy retreat with a luxurious en-suite bathroom and walk-in closet for added convenience.
#
# Enjoy outdoor living on the inviting patio and large backyard, ideal for summer BBQs and friendly gatherings. With its family-friendly atmosphere and top-rated schools, Willow Creek is perfect for those seeking comfort and community. Residents can take advantage of the nearby parks, shopping centers, and dining options, all while enjoying leisurely strolls along the picturesque tree-lined streets. This home offers an excellent blend of comfort, style, and community in the charming Willow Creek neighborhood.
#
# ====================================================================================================
#
# Welcome to your future home in the friendly Pinecrest Hills neighborhood, where you’ll find this charming 4-bedroom, 3-bathroom residence. Designed with comfort in mind, the spacious living room invites you in with its large windows that fill the space with an abundance of natural light, illuminating the beautiful hardwood floors and modern finishes.
#
# The heart of this home is the gourmet kitchen, perfect for family gatherings and culinary adventures, featuring high-end appliances and a generous center island.
#
# The relaxed atmosphere continues with a luxurious master suite that includes a spa-like bathroom and a walk-in closet, offering a private retreat after a long day.
#
# Step outside to enjoy the landscaped backyard with a cozy patio that’s ideal for outdoor entertaining or simply unwinding in the fresh air.
#
# Experience the welcoming charm of Pinecrest Hills, known for its friendly neighbors and serene living environment, making it a delightful place to call home.
#
# ====================================================================================================
